# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('terrorism_data_clean.csv', index_col=False)
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
df.isna().sum()
# Out:
# iyear                   0
# extended                0
# country_txt             0
# region_txt              0
# city                  434
# attacktype1_txt         0
# targtype1_txt           0
# targsubtype1_txt    10373
# weaptype1_txt           0
# gname                   0
# nkilled                 0
# nwounded                0
# start_year              0
# dtype: int64

# %%
# df = df.fillna('Unknown')
# df.isna().sum()
# df.to_csv('terrorism_data_clean.csv', index=False)

# %%
df_pcp_1970 = df[df['start_year'] == 1970][['iyear', 'country_txt', 'city', 'gname', 'attacktype1_txt', 'targtype1_txt', 'targsubtype1_txt', 'weaptype1_txt']]
df_pcp_1970[df_pcp_1970['country_txt'] == 'Mexico']
# Out:
#       iyear country_txt         city                               gname  \
# 1      1970      Mexico  Mexico city  23rd of September Communist League
# 474    1970      Mexico  Mexico city                             Unknown
# 1617   1972      Mexico    Monterrey                             Unknown
# 1871   1973      Mexico  Guadalajara         Revolutionary Student Front
# 2061   1973      Mexico  Guadalajara         Revolutionary Student Front
# ...     ...         ...          ...                                 ...
# 9181   1979      Mexico  Mexico City  23rd of September Communist League
# 9182   1979      Mexico  Mexico City  23rd of September Communist League
# 9183   1979      Mexico  Mexico City  23rd of September Communist League
# 9326   1979      Mexico  Mexico City  23rd of September Communist League
# 9461   1979      Mexico  Mexico City                             Unknown
#
#                   attacktype1_txt            targtype1_txt  \
# ...

# %%
df_pcp_1970.isna().sum()
# Out:
# iyear               0
# country_txt         0
# city                0
# gname               0
# attacktype1_txt     0
# targtype1_txt       0
# targsubtype1_txt    0
# weaptype1_txt       0
# dtype: int64

# %%
df_pcp_1970.head()
# Out:
#    iyear         country_txt           city  \
# 0   1970  Dominican Republic  Santo Domingo
# 1   1970              Mexico    Mexico city
# 2   1970         Philippines        Unknown
# 3   1970              Greece         Athens
# 4   1970               Japan        Fukouka
#
#                                 gname                 attacktype1_txt  \
# 0                              MANO-D                   Assassination
# 1  23rd of September Communist League     Hostage Taking (Kidnapping)
# 2                             Unknown                   Assassination
# 3                             Unknown               Bombing/Explosion
# 4                             Unknown  Facility/Infrastructure Attack
#
#                  targtype1_txt  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# 3      Government (Diplomatic)
# 4      Government (Diplomatic)
#
#                                     targsubtype1_txt weaptype1_txt
# ...
